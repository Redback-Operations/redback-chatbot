# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\dell\anaconda3\lib\site-packages (4.32.1)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dell\anaconda3
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.3.11  |       haa95532_0         128 KB
#     certifi-2024.2.2           |  py311haa95532_0         162 KB
#     cpuonly-2.0                |                0           2 KB  pytorch
#     h5py-3.11.0                |  py311h765d3d0_0         1.2 MB
#     libjpeg-turbo-2.0.0        |       h196d8e1_0         618 KB
#     libuv-1.44.2               |       h2bbff1b_0         288 KB
#     openssl-3.0.13             |       h2bbff1b_1         7.5 MB
#     pytorch-2.2.2              |     py3.11_cpu_0       171.8 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     torchaudio-2.2.2           |        py311_cpu         5.8 MB  pytorch
#     torchvision-0.17.2         |        py311_cpu         6.7 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       194.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cpuonly            pytorch/noarch::cpuonly-2.0-0
#   h5py               pkgs/main/win-64::h5py-3.11.0-py311h765d3d0_0
#   libjpeg-turbo      pkgs/main/win-64::libjpeg-turbo-2.0.0-h196d8e1_0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#   pytorch            pytorch/win-64::pytorch-2.2.2-py3.11_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#   torchaudio         pytorch/win-64::torchaudio-2.2.2-py311_cpu
#   torchvision        pytorch/win-64::torchvision-0.17.2-py311_cpu
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.08.22-haa95532_0 --> 2024.3.11-haa95532_0
#   certifi                         2023.7.22-py311haa95532_0 --> 2024.2.2-py311haa95532_0
#   openssl                                 3.0.10-h2bbff1b_2 --> 3.0.13-h2bbff1b_1
#
#
#
# Downloading and Extracting Packages
#
# openssl-3.0.13       | 7.5 MB    |            |   0%
#
# libuv-1.44.2         | 288 KB    |            |   0%
#
#
# pytorch-2.2.2        | 171.8 MB  |            |   0%
#
#
#
# certifi-2024.2.2     | 162 KB    |            |   0%
#
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    |            |   0%
#
#
#
#
#
# ca-certificates-2024 | 128 KB    |            |   0%
#
#
#
#
#
#
# cpuonly-2.0          | 2 KB      |            |   0%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    |            |   0%
#
#
#
#
#
#
#
#
# h5py-3.11.0          | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    |            |   0%
#
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | 2          |   3%
# openssl-3.0.13       | 7.5 MB    |            |   0%
#
# libuv-1.44.2         | 288 KB    | 5          |   6%
#
#
#
# certifi-2024.2.2     | 162 KB    | 9          |  10%
#
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | ########   |  80%
# openssl-3.0.13       | 7.5 MB    | 3          |   4%
#
#
# pytorch-2.2.2        | 171.8 MB  |            |   0%
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | #2         |  12%
#
#
#
#
#
#
#
#
# h5py-3.11.0          | 1.2 MB    | 1          |   1%
#
#
#
# certifi-2024.2.2     | 162 KB    | ########## | 100%
#
#
#
# certifi-2024.2.2     | 162 KB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  |            |   0%
# openssl-3.0.13       | 7.5 MB    | #3         |  13%
#
#
#
#
#
#
#
#
# h5py-3.11.0          | 1.2 MB    | #####2     |  53%
#
# libuv-1.44.2         | 288 KB    | ########## | 100%
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | ########## | 100%
#
# libuv-1.44.2         | 288 KB    | ########## | 100%
#
#
#
#
#
# ca-certificates-2024 | 128 KB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  |            |   1%
#
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
# openssl-3.0.13       | 7.5 MB    | #8         |  18%
#
#
#
#
#
#
#
#
# h5py-3.11.0          | 1.2 MB    | #########3 |  93%
#
#
# pytorch-2.2.2        | 171.8 MB  | 1          |   1%
# openssl-3.0.13       | 7.5 MB    | ##5        |  26%
#
#
# pytorch-2.2.2        | 171.8 MB  | 1          |   1%
# openssl-3.0.13       | 7.5 MB    | ###4       |  34%
#
#
# pytorch-2.2.2        | 171.8 MB  | 1          |   2%
# openssl-3.0.13       | 7.5 MB    | ####2      |  42%
#
#
# pytorch-2.2.2        | 171.8 MB  | 2          |   2%
# openssl-3.0.13       | 7.5 MB    | ####9      |  49%
#
#
# pytorch-2.2.2        | 171.8 MB  | 2          |   3%
# openssl-3.0.13       | 7.5 MB    | #####6     |  57%
#
#
#
#
#
#
#
#
# h5py-3.11.0          | 1.2 MB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | 3          |   3%
# openssl-3.0.13       | 7.5 MB    | ######4    |  65%
#
#
# pytorch-2.2.2        | 171.8 MB  | 3          |   4%
# openssl-3.0.13       | 7.5 MB    | #######1   |  72%
#
#
# pytorch-2.2.2        | 171.8 MB  | 4          |   4%
# openssl-3.0.13       | 7.5 MB    | #######8   |  79%
#
#
# pytorch-2.2.2        | 171.8 MB  | 4          |   5%
# openssl-3.0.13       | 7.5 MB    | ########5  |  86%
#
#
#
#
#
#
# cpuonly-2.0          | 2 KB      | ########## | 100%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    |            |   0%
#
#
# pytorch-2.2.2        | 171.8 MB  | 5          |   5%
#
#
#
#
#
#
# cpuonly-2.0          | 2 KB      | ########## | 100%
# openssl-3.0.13       | 7.5 MB    | #########2 |  93%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | 4          |   4%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    |            |   0%
#
#
# pytorch-2.2.2        | 171.8 MB  | 5          |   6%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | #3         |  14%
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | 4          |   4%
#
#
#
#
#
#
#
#
#
# pytorch-mutex-1.0    | 3 KB      | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | 6          |   6%
# openssl-3.0.13       | 7.5 MB    | #########9 |  99%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #          |  11%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #7         |  17%
#
#
# pytorch-2.2.2        | 171.8 MB  | 6          |   7%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ###5       |  36%
#
#
# pytorch-2.2.2        | 171.8 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ##5        |  26%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ###2       |  33%
#
#
# pytorch-2.2.2        | 171.8 MB  | 7          |   7%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ###9       |  40%
#
#
# pytorch-2.2.2        | 171.8 MB  | 7          |   8%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ####7      |  48%
# openssl-3.0.13       | 7.5 MB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | 7          |   8%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ######1    |  61%
#
#
# pytorch-2.2.2        | 171.8 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #####4     |  55%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ######7    |  68%
#
#
# pytorch-2.2.2        | 171.8 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ######1    |  62%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | #######3   |  74%
#
#
# pytorch-2.2.2        | 171.8 MB  | 8          |   9%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #######    |  71%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ########   |  80%
#
#
# pytorch-2.2.2        | 171.8 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #######8   |  79%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ########6  |  87%
#
#
# pytorch-2.2.2        | 171.8 MB  | 9          |   9%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | #########4 |  95%
#
#
# pytorch-2.2.2        | 171.8 MB  | 9          |  10%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | #########8 |  98%
#
#
# pytorch-2.2.2        | 171.8 MB  | 9          |  10%
#
#
# pytorch-2.2.2        | 171.8 MB  | #          |  10%
#
#
# pytorch-2.2.2        | 171.8 MB  | #          |  11%
#
#
# pytorch-2.2.2        | 171.8 MB  | #1         |  11%
#
#
# pytorch-2.2.2        | 171.8 MB  | #1         |  12%
#
#
# pytorch-2.2.2        | 171.8 MB  | #2         |  13%
#
#
# pytorch-2.2.2        | 171.8 MB  | #3         |  13%
#
#
# pytorch-2.2.2        | 171.8 MB  | #3         |  14%
#
#
# pytorch-2.2.2        | 171.8 MB  | #4         |  14%
#
#
# pytorch-2.2.2        | 171.8 MB  | #5         |  15%
#
#
# pytorch-2.2.2        | 171.8 MB  | #5         |  16%
#
#
# pytorch-2.2.2        | 171.8 MB  | #6         |  17%
#
#
# pytorch-2.2.2        | 171.8 MB  | #7         |  17%
#
#
# pytorch-2.2.2        | 171.8 MB  | #8         |  18%
#
#
# pytorch-2.2.2        | 171.8 MB  | #9         |  19%
#
#
# pytorch-2.2.2        | 171.8 MB  | #9         |  20%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##         |  21%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##1        |  21%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##2        |  22%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##2        |  23%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##3        |  24%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##4        |  24%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##5        |  25%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##5        |  26%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##6        |  27%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##7        |  28%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##8        |  28%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##9        |  29%
#
#
# pytorch-2.2.2        | 171.8 MB  | ##9        |  30%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###        |  30%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###1       |  31%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###1       |  32%
#
#
#
#
#
#
#
# torchvision-0.17.2   | 6.7 MB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.2.2     | 5.8 MB    | ########## | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###3       |  33%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###3       |  34%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###4       |  35%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###5       |  35%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###5       |  36%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###6       |  36%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###7       |  37%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###7       |  38%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###8       |  38%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###9       |  39%
#
#
# pytorch-2.2.2        | 171.8 MB  | ###9       |  40%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####       |  40%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####1      |  41%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####1      |  42%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####2      |  43%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####3      |  43%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####4      |  44%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####4      |  45%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####5      |  46%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####6      |  47%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####7      |  47%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####7      |  48%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####8      |  49%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####9      |  49%
#
#
# pytorch-2.2.2        | 171.8 MB  | ####9      |  50%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####      |  50%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####1     |  51%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####1     |  52%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####2     |  52%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####2     |  53%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####3     |  54%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####4     |  54%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####5     |  55%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####5     |  56%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####6     |  57%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####7     |  57%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####8     |  58%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####9     |  59%
#
#
# pytorch-2.2.2        | 171.8 MB  | #####9     |  60%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######     |  61%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######1    |  61%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######2    |  62%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######2    |  63%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######3    |  64%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######4    |  64%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######4    |  65%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######5    |  66%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######6    |  66%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######6    |  67%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######7    |  68%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######8    |  68%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######8    |  69%
#
#
# pytorch-2.2.2        | 171.8 MB  | ######9    |  70%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######    |  70%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######1   |  71%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######1   |  72%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######2   |  72%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######2   |  73%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######3   |  74%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######4   |  75%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######5   |  75%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######6   |  76%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######6   |  77%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######7   |  78%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######8   |  78%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######9   |  79%
#
#
# pytorch-2.2.2        | 171.8 MB  | #######9   |  80%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########   |  81%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########1  |  81%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########2  |  82%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########2  |  83%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########3  |  84%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########4  |  84%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########5  |  85%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########6  |  86%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########6  |  87%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########7  |  88%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########8  |  88%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########9  |  89%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########9  |  90%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########  |  91%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########1 |  91%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########2 |  92%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########3 |  93%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########3 |  94%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########4 |  95%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########5 |  95%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########6 |  96%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########6 |  97%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########7 |  98%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########8 |  98%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########9 |  99%
#
#
# pytorch-2.2.2        | 171.8 MB  | #########9 | 100%
#
#
# pytorch-2.2.2        | 171.8 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::_anaconda_depends==2023.09=py311_mkl_1
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dell\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.12.3         |  py311haa95532_0         156 KB
#     aiohttp-3.9.5              |  py311h2bbff1b_0         800 KB
#     anyio-4.2.0                |  py311haa95532_0         238 KB
#     arrow-cpp-14.0.2           |       ha81ea56_1         8.5 MB
#     astropy-5.3.4              |  py311hd7041d2_0         9.7 MB
#     async-lru-2.0.4            |  py311haa95532_0          21 KB
#     attrs-23.1.0               |  py311haa95532_0         165 KB
#     autopep8-2.0.4             |     pyhd3eb1b0_0          44 KB
#     aws-c-auth-0.6.19          |       h2bbff1b_0          95 KB
#     aws-c-cal-0.5.20           |       h2bbff1b_0          41 KB
#     aws-c-common-0.8.5         |       h2bbff1b_0         198 KB
#     aws-c-compression-0.2.16   |       h2bbff1b_0          21 KB
#     aws-c-event-stream-0.2.15  |       hd77b12b_0          50 KB
#     aws-c-http-0.6.25          |       h2bbff1b_0         181 KB
#     aws-c-io-0.13.10           |       h2bbff1b_0         153 KB
#     aws-c-mqtt-0.7.13          |       h2bbff1b_0          65 KB
#     aws-c-s3-0.1.51            |       h2bbff1b_0          68 KB
#     aws-c-sdkutils-0.1.6       |       h2bbff1b_0          48 KB
#     aws-checksums-0.1.13       |       h2bbff1b_0          50 KB
#     aws-crt-cpp-0.18.16        |       hd77b12b_0         194 KB
#     aws-sdk-cpp-1.10.55        |       hd77b12b_0         2.1 MB
#     black-24.3.0               |  py311haa95532_0         402 KB
#     bokeh-3.4.0                |  py311h746a85d_1         5.9 MB
#     boost-cpp-1.82.0           |       h59b6b97_2          11 KB
#     botocore-1.34.69           |  py311haa95532_0         7.3 MB
#     bottleneck-1.3.7           |  py311hd7041d2_0         134 KB
#     brotli-1.0.9               |       h2bbff1b_8          19 KB
#     brotli-bin-1.0.9           |       h2bbff1b_8          29 KB
#     brotli-python-1.0.9        |  py311hd77b12b_8         347 KB
#     bzip2-1.0.8                |       h2bbff1b_6          90 KB
#     c-blosc2-2.12.0            |       h2f4ed9d_0         222 KB
#     cffi-1.16.0                |  py311h2bbff1b_1         313 KB
#     click-8.1.7                |  py311haa95532_0         222 KB
#     colorcet-3.1.0             |  py311haa95532_0         614 KB
#     comm-0.2.1                 |  py311haa95532_0          17 KB
#     conda-index-0.4.0          |     pyhd3eb1b0_0         173 KB
#     conda-repo-cli-1.0.88      |  py311haa95532_0         200 KB
#     constantly-23.10.4         |  py311haa95532_0          33 KB
#     contourpy-1.2.0            |  py311h59b6b97_0         218 KB
#     cookiecutter-2.6.0         |  py311haa95532_0         161 KB
#     cryptography-42.0.5        |  py311h89fc84f_1         1.2 MB
#     cssselect-1.2.0            |  py311haa95532_0          49 KB
#     curl-8.7.1                 |       he2ea4bf_0         172 KB
#     cytoolz-0.12.2             |  py311h2bbff1b_0         339 KB
#     dal-2023.1.1               |   h59b6b97_48682        26.5 MB
#     dask-2024.5.0              |  py311haa95532_0           7 KB
#     dask-core-2024.5.0         |  py311haa95532_0         3.0 MB
#     dask-expr-1.1.0            |  py311haa95532_0         486 KB
#     datashader-0.16.0          |  py311haa95532_0        17.1 MB
#     dill-0.3.8                 |  py311haa95532_0         263 KB
#     distributed-2024.5.0       |  py311haa95532_0         1.7 MB
#     filelock-3.13.1            |  py311haa95532_0          24 KB
#     flake8-7.0.0               |  py311haa95532_0         137 KB
#     flask-2.2.5                |  py311haa95532_0         208 KB
#     fmt-9.1.0                  |       h6d14046_1         200 KB
#     fonttools-4.51.0           |  py311h2bbff1b_0         2.6 MB
#     frozenlist-1.4.0           |  py311h2bbff1b_0          47 KB
#     fsspec-2024.3.1            |  py311haa95532_0         374 KB
#     gflags-2.2.2               |       hd77b12b_1         247 KB
#     glog-0.5.0                 |       hd77b12b_1          93 KB
#     gmpy2-2.1.2                |  py311h7f96b67_0         140 KB
#     greenlet-3.0.1             |  py311hd77b12b_0         222 KB
#     holoviews-1.18.3           |  py311haa95532_0         5.2 MB
#     huggingface_hub-0.20.3     |  py311haa95532_0         515 KB
#     hvplot-0.10.0              |  py311haa95532_0         351 KB
#     icu-73.1                   |       h6c2663c_0        29.5 MB
#     idna-3.7                   |  py311haa95532_0         133 KB
#     imageio-2.33.1             |  py311haa95532_0         645 KB
#     imbalanced-learn-0.11.0    |  py311haa95532_1         383 KB
#     importlib-metadata-7.0.1   |  py311haa95532_0          49 KB
#     importlib_metadata-7.0.1   |       hd3eb1b0_0           8 KB
#     incremental-22.10.0        |     pyhd3eb1b0_0          18 KB
#     intel-openmp-2023.1.0      |   h59b6b97_46320         2.7 MB
#     ipykernel-6.28.0           |  py311haa95532_0         246 KB
#     ipython-8.20.0             |  py311haa95532_0         1.5 MB
#     ipywidgets-8.1.2           |  py311haa95532_0         252 KB
#     itemloaders-1.1.0          |  py311haa95532_0          31 KB
#     jinja2-3.1.3               |  py311haa95532_0         354 KB
#     jmespath-1.0.1             |  py311haa95532_0          51 KB
#     joblib-1.4.0               |  py311haa95532_0         531 KB
#     jsonpatch-1.33             |  py311haa95532_1          63 KB
#     jsonschema-4.19.2          |  py311haa95532_0         213 KB
#     jsonschema-specifications-2023.7.1|  py311haa95532_0          16 KB
#     jupyter-1.0.0              |  py311haa95532_9           8 KB
#     jupyter-lsp-2.2.0          |  py311haa95532_0         107 KB
#     jupyter_client-8.6.0       |  py311haa95532_0         252 KB
#     jupyter_core-5.5.0         |  py311haa95532_0         112 KB
#     jupyter_events-0.8.0       |  py311haa95532_0          58 KB
#     jupyter_server-2.10.0      |  py311haa95532_0         596 KB
#     jupyter_server_terminals-0.4.4|  py311haa95532_1          29 KB
#     jupyterlab-4.0.11          |  py311haa95532_0         4.6 MB
#     jupyterlab_server-2.25.1   |  py311haa95532_0         114 KB
#     jupyterlab_widgets-3.0.10  |  py311haa95532_0         196 KB
#     keyring-24.3.1             |  py311haa95532_0         100 KB
#     lazy-object-proxy-1.10.0   |  py311h2bbff1b_0          39 KB
#     lazy_loader-0.3            |  py311haa95532_0          21 KB
#     libarchive-3.6.2           |       hb62f4d4_3         1.8 MB
#     libboost-1.82.0            |       h3399ecb_2        23.1 MB
#     libbrotlicommon-1.0.9      |       h2bbff1b_8          79 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_8          39 KB
#     libbrotlienc-1.0.9         |       h2bbff1b_8         261 KB
#     libcurl-8.7.1              |       h86230a5_0         359 KB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     libffi-3.4.4               |       hd77b12b_1         122 KB
#     libiconv-1.16              |       h2bbff1b_3         685 KB
#     libmamba-1.5.8             |       h99b1521_2         3.9 MB
#     libmambapy-1.5.8           |  py311h77c03ed_2         674 KB
#     libpq-12.17                |       h906ac69_0         3.2 MB
#     libsolv-0.7.24             |       h23ce68f_1         465 KB
#     libssh2-1.11.0             |       h291bd65_0         285 KB
#     libxml2-2.10.4             |       h0ad7f3c_2         2.9 MB
#     llvmlite-0.42.0            |  py311hf2fb9eb_0        18.6 MB
#     lxml-5.2.1                 |  py311h09808a7_0         1.1 MB
#     lz4-c-1.9.4                |       h2bbff1b_1         152 KB
#     markupsafe-2.1.3           |  py311h2bbff1b_0          28 KB
#     matplotlib-3.8.4           |  py311haa95532_0           9 KB
#     matplotlib-base-3.8.4      |  py311hf62ec03_0         9.2 MB
#     mistune-2.0.4              |  py311haa95532_0         108 KB
#     mkl-2023.1.0               |   h6b88ed4_46358       155.9 MB
#     more-itertools-10.1.0      |  py311haa95532_0         107 KB
#     mpc-1.1.0                  |       h7edee0f_1         260 KB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     mpir-3.0.0                 |       hec2e145_1         1.3 MB
#     multidict-6.0.4            |  py311h2bbff1b_0          54 KB
#     navigator-updater-0.5.0    |  py311haa95532_0         2.3 MB
#     nbclient-0.8.0             |  py311haa95532_0         137 KB
#     nbconvert-7.10.0           |  py311haa95532_0         532 KB
#     nest-asyncio-1.6.0         |  py311haa95532_0          17 KB
#     notebook-7.0.8             |  py311haa95532_0         3.4 MB
#     notebook-shim-0.2.3        |  py311haa95532_0          27 KB
#     numba-0.59.1               |  py311hf62ec03_0         5.9 MB
#     numexpr-2.8.7              |  py311h1fcbade_0         160 KB
#     numpy-1.26.4               |  py311hdab7c0b_0          11 KB
#     numpy-base-1.26.4          |  py311hd01c5d8_0         9.1 MB
#     openpyxl-3.1.2             |  py311h2bbff1b_0         668 KB
#     overrides-7.4.0            |  py311haa95532_0          38 KB
#     packaging-23.2             |  py311haa95532_0         173 KB
#     pandas-2.2.1               |  py311hea22821_0        14.6 MB
#     panel-1.4.2                |  py311haa95532_0        18.8 MB
#     param-2.1.0                |  py311haa95532_0         269 KB
#     parsel-1.8.1               |  py311haa95532_0          52 KB
#     partd-1.4.1                |  py311haa95532_0          49 KB
#     pcre2-10.42                |       h0ff8eda_1         728 KB
#     pillow-10.3.0              |  py311h2bbff1b_0         995 KB
#     pkginfo-1.10.0             |  py311haa95532_0          93 KB
#     plotly-5.19.0              |  py311h746a85d_0         5.8 MB
#     prompt-toolkit-3.0.43      |  py311haa95532_0         746 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     py-cpuinfo-9.0.0           |  py311haa95532_0          87 KB
#     pyarrow-14.0.2             |  py311h847bd2a_0         3.7 MB
#     pybind11-abi-5             |       hd3eb1b0_0          14 KB
#     pycodestyle-2.11.1         |  py311haa95532_0          95 KB
#     pycosat-0.6.6              |  py311h2bbff1b_1          94 KB
#     pydantic-1.10.12           |  py311h2bbff1b_1         1.6 MB
#     pyflakes-3.2.0             |  py311haa95532_0         173 KB
#     pyjwt-2.8.0                |  py311haa95532_0          87 KB
#     pylint-venv-3.0.3          |  py311haa95532_0          13 KB
#     pyodbc-5.0.1               |  py311hd77b12b_0          66 KB
#     pyopenssl-24.0.0           |  py311haa95532_0         125 KB
#     pyqt-5.15.10               |  py311hd77b12b_0         4.1 MB
#     pyqt5-sip-12.13.0          |  py311h2bbff1b_0          75 KB
#     pyqtwebengine-5.15.10      |  py311hd77b12b_0         134 KB
#     pytables-3.9.2             |  py311h91a9f6a_0         1.5 MB
#     python-dateutil-2.9.0post0 |  py311haa95532_0         354 KB
#     python-lsp-black-2.0.0     |  py311haa95532_0          17 KB
#     python-lsp-jsonrpc-1.1.2   |     pyhd3eb1b0_0          12 KB
#     python-lsp-server-1.10.0   |  py311haa95532_0         179 KB
#     pytoolconfig-1.2.6         |  py311haa95532_0          36 KB
#     pytz-2024.1                |  py311haa95532_0         223 KB
#     pyviz_comms-3.0.2          |  py311haa95532_0          57 KB
#     pywavelets-1.5.0           |  py311hd7041d2_0         3.6 MB
#     pywin32-ctypes-0.2.2       |  py311haa95532_0          56 KB
#     pyyaml-6.0.1               |  py311h2bbff1b_0         185 KB
#     pyzmq-25.1.2               |  py311hd77b12b_0         493 KB
#     qdarkstyle-3.2.3           |     pyhd3eb1b0_0         615 KB
#     qt-main-5.15.2             |      h19c9488_10        59.4 MB
#     qtconsole-5.5.1            |  py311haa95532_0         271 KB
#     qtpy-2.4.1                 |  py311haa95532_0         148 KB
#     queuelib-1.6.2             |  py311haa95532_0          36 KB
#     referencing-0.30.2         |  py311haa95532_0          78 KB
#     regex-2023.10.3            |  py311h2bbff1b_0         389 KB
#     reproc-14.2.4              |       hd77b12b_2          40 KB
#     reproc-cpp-14.2.4          |       hd77b12b_2          34 KB
#     requests-2.31.0            |  py311haa95532_1         125 KB
#     rich-13.3.5                |  py311haa95532_0         566 KB
#     rope-1.12.0                |  py311haa95532_0         596 KB
#     rpds-py-0.10.6             |  py311h062c2fa_0         202 KB
#     s3fs-2024.3.1              |  py311haa95532_0          80 KB
#     safetensors-0.4.2          |  py311hcbdf901_0         290 KB
#     scikit-image-0.22.0        |  py311hb4ba03d_0         9.9 MB
#     scikit-learn-1.4.2         |  py311hf62ec03_1         9.0 MB
#     scipy-1.13.0               |  py311h9f229c6_0        25.9 MB
#     scrapy-2.11.1              |  py311haa95532_0         870 KB
#     send2trash-1.8.2           |  py311haa95532_0          81 KB
#     sip-6.7.12                 |  py311hd77b12b_0         615 KB
#     snappy-1.1.10              |       h6c2663c_1          92 KB
#     sniffio-1.3.0              |  py311haa95532_0          18 KB
#     soupsieve-2.5              |  py311haa95532_0          93 KB
#     spyder-5.5.1               |  py311haa95532_0        11.0 MB
#     spyder-kernels-2.5.0       |  py311haa95532_0         204 KB
#     sqlalchemy-2.0.25          |  py311h2bbff1b_0         3.8 MB
#     sqlite-3.45.3              |       h2bbff1b_0         973 KB
#     sympy-1.12                 |  py311haa95532_0        14.4 MB
#     tabulate-0.9.0             |  py311haa95532_0          90 KB
#     tk-8.6.14                  |       h0416ee5_0         3.5 MB
#     tokenizers-0.15.1          |  py311h49fca51_0         1.8 MB
#     tomli-2.0.1                |  py311haa95532_0          31 KB
#     tornado-6.3.3              |  py311h2bbff1b_0         856 KB
#     tqdm-4.66.2                |  py311h746a85d_0         191 KB
#     transformers-4.37.2        |  py311haa95532_0        10.0 MB
#     twisted-23.10.0            |  py311haa95532_0         6.8 MB
#     typing-extensions-4.11.0   |  py311haa95532_0          10 KB
#     typing_extensions-4.11.0   |  py311haa95532_0          77 KB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     unicodedata2-15.1.0        |  py311h2bbff1b_0         521 KB
#     urllib3-2.2.1              |  py311haa95532_0         228 KB
#     utf8proc-2.6.1             |       h2bbff1b_1          96 KB
#     vc-14.2                    |       h2eaa2aa_1          10 KB
#     vs2015_runtime-14.29.30133 |       h43f2093_3         1.1 MB
#     w3lib-2.1.2                |  py311haa95532_0          44 KB
#     websocket-client-1.8.0     |  py311haa95532_0         147 KB
#     widgetsnbextension-4.0.10  |  py311haa95532_0         949 KB
#     xz-5.4.6                   |       h8cc25b3_1         609 KB
#     yaml-cpp-0.8.0             |       hd77b12b_1         2.1 MB
#     yapf-0.40.2                |  py311haa95532_0         492 KB
#     yarl-1.9.3                 |  py311h2bbff1b_0         118 KB
#     zeromq-4.3.5               |       hd77b12b_0         5.2 MB
#     zict-3.0.0                 |  py311haa95532_0         119 KB
#     zipp-3.17.0                |  py311haa95532_0          25 KB
#     zlib-1.2.13                |       h8cc25b3_1         131 KB
#     zstandard-0.22.0           |  py311h3469f8a_0         354 KB
#     zstd-1.5.5                 |       hd43e919_2         720 KB
#     ------------------------------------------------------------
#                                            Total:       626.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   async-lru          pkgs/main/win-64::async-lru-2.0.4-py311haa95532_0
#   aws-c-auth         pkgs/main/win-64::aws-c-auth-0.6.19-h2bbff1b_0
#   aws-c-cal          pkgs/main/win-64::aws-c-cal-0.5.20-h2bbff1b_0
#   aws-c-compression  pkgs/main/win-64::aws-c-compression-0.2.16-h2bbff1b_0
#   aws-c-http         pkgs/main/win-64::aws-c-http-0.6.25-h2bbff1b_0
#   aws-c-io           pkgs/main/win-64::aws-c-io-0.13.10-h2bbff1b_0
#   aws-c-mqtt         pkgs/main/win-64::aws-c-mqtt-0.7.13-h2bbff1b_0
#   aws-c-s3           pkgs/main/win-64::aws-c-s3-0.1.51-h2bbff1b_0
#   aws-c-sdkutils     pkgs/main/win-64::aws-c-sdkutils-0.1.6-h2bbff1b_0
#   aws-crt-cpp        pkgs/main/win-64::aws-crt-cpp-0.18.16-hd77b12b_0
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311hd77b12b_8
#   dask-expr          pkgs/main/win-64::dask-expr-1.1.0-py311haa95532_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.1.2-py311h7f96b67_0
#   jsonschema-specif~ pkgs/main/win-64::jsonschema-specifications-2023.7.1-py311haa95532_0
#   jupyter-lsp        pkgs/main/win-64::jupyter-lsp-2.2.0-py311haa95532_0
#   jupyter_server_te~ pkgs/main/win-64::jupyter_server_terminals-0.4.4-py311haa95532_1
#   mpc                pkgs/main/win-64::mpc-1.1.0-h7edee0f_1
#   mpfr               pkgs/main/win-64::mpfr-4.0.2-h62dcd97_1
#   mpir               pkgs/main/win-64::mpir-3.0.0-hec2e145_1
#   overrides          pkgs/main/win-64::overrides-7.4.0-py311haa95532_0
#   referencing        pkgs/main/win-64::referencing-0.30.2-py311haa95532_0
#   rich               pkgs/main/win-64::rich-13.3.5-py311haa95532_0
#   rpds-py            pkgs/main/win-64::rpds-py-0.10.6-py311h062c2fa_0
#   tomli              pkgs/main/win-64::tomli-2.0.1-py311haa95532_0
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py311h2bbff1b_0
#
# The following packages will be REMOVED:
#
#   aiofiles-22.1.0-py311haa95532_0
#   aiosqlite-0.18.0-py311haa95532_0
#   async-timeout-4.0.2-py311haa95532_0
#   backcall-0.2.0-pyhd3eb1b0_0
#   brotlipy-0.7.0-py311h2bbff1b_1002
#   datasets-2.12.0-py311haa95532_0
#   datashape-0.5.4-py311haa95532_1
#   glib-2.69.1-h5dc1a3c_2
#   ipython_genutils-0.2.0-pyhd3eb1b0_1
#   jinja2-time-0.2.0-pyhd3eb1b0_3
#   jupyter_server_fileid-0.9.0-py311haa95532_0
#   jupyter_server_ydoc-0.8.0-py311haa95532_1
#   jupyter_ydoc-0.2.4-py311haa95532_0
#   libwebp-1.3.2-hbc33d0d_0
#   multiprocess-0.70.14-py311haa95532_0
#   munkres-1.1.4-py_0
#   nbclassic-0.5.5-py311haa95532_0
#   pathlib-1.0.1-pyhd3eb1b0_1
#   pcre-8.45-hd77b12b_0
#   poyo-0.5.0-pyhd3eb1b0_0
#   pyrsistent-0.18.0-py311h2bbff1b_0
#   python-xxhash-2.0.2-py311h2bbff1b_1
#   qtwebkit-5.212-h2bbfb41_5
#   responses-0.13.3-pyhd3eb1b0_0
#   toml-0.10.2-pyhd3eb1b0_0
#   xxhash-0.8.0-h2bbff1b_3
#   y-py-0.5.9-py311hb6bf4ef_0
#   ypy-websocket-0.8.2-py311haa95532_0
#
# The following packages will be UPDATED:
#
#   aiobotocore                         2.5.0-py311haa95532_0 --> 2.12.3-py311haa95532_0
#   aiohttp                             3.8.5-py311h2bbff1b_0 --> 3.9.5-py311h2bbff1b_0
#   anyio                               3.5.0-py311haa95532_0 --> 4.2.0-py311haa95532_0
#   arrow-cpp                               11.0.0-ha81ea56_2 --> 14.0.2-ha81ea56_1
#   astropy                               5.1-py311h5bb9823_0 --> 5.3.4-py311hd7041d2_0
#   attrs                              22.1.0-py311haa95532_0 --> 23.1.0-py311haa95532_0
#   autopep8                               1.6.0-pyhd3eb1b0_1 --> 2.0.4-pyhd3eb1b0_0
#   aws-c-common                             0.6.8-h2bbff1b_1 --> 0.8.5-h2bbff1b_0
#   aws-c-event-stream                       0.1.6-hd77b12b_6 --> 0.2.15-hd77b12b_0
#   aws-checksums                           0.1.11-h2bbff1b_2 --> 0.1.13-h2bbff1b_0
#   aws-sdk-cpp                            1.8.185-hd77b12b_1 --> 1.10.55-hd77b12b_0
#   black                              23.3.0-py311haa95532_0 --> 24.3.0-py311haa95532_0
#   bokeh                               3.2.1-py311h746a85d_0 --> 3.4.0-py311h746a85d_1
#   boost-cpp                               1.82.0-h59b6b97_1 --> 1.82.0-h59b6b97_2
#   botocore                          1.29.76-py311haa95532_0 --> 1.34.69-py311haa95532_0
#   bottleneck                          1.3.5-py311h5bb9823_0 --> 1.3.7-py311hd7041d2_0
#   brotli                                   1.0.9-h2bbff1b_7 --> 1.0.9-h2bbff1b_8
#   brotli-bin                               1.0.9-h2bbff1b_7 --> 1.0.9-h2bbff1b_8
#   bzip2                                    1.0.8-he774522_0 --> 1.0.8-h2bbff1b_6
#   c-blosc2                                 2.8.0-hd77b12b_0 --> 2.12.0-h2f4ed9d_0
#   cffi                               1.15.1-py311h2bbff1b_3 --> 1.16.0-py311h2bbff1b_1
#   click                               8.0.4-py311haa95532_0 --> 8.1.7-py311haa95532_0
#   colorcet                            3.0.1-py311haa95532_0 --> 3.1.0-py311haa95532_0
#   comm                                0.1.2-py311haa95532_0 --> 0.2.1-py311haa95532_0
#   conda-index        pkgs/main/win-64::conda-index-0.3.0-p~ --> pkgs/main/noarch::conda-index-0.4.0-pyhd3eb1b0_0
#   conda-repo-cli                     1.0.75-py311haa95532_0 --> 1.0.88-py311haa95532_0
#   constantly                         15.1.0-py311haa95532_0 --> 23.10.4-py311haa95532_0
#   contourpy                           1.0.5-py311h59b6b97_0 --> 1.2.0-py311h59b6b97_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.3-~ --> pkgs/main/win-64::cookiecutter-2.6.0-py311haa95532_0
#   cryptography                       41.0.3-py311h89fc84f_0 --> 42.0.5-py311h89fc84f_1
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyh~ --> pkgs/main/win-64::cssselect-1.2.0-py311haa95532_0
#   curl                                     8.1.1-h2bbff1b_0 --> 8.7.1-he2ea4bf_0
#   cytoolz                            0.12.0-py311h2bbff1b_0 --> 0.12.2-py311h2bbff1b_0
#   dal                               2023.1.1-h59b6b97_48681 --> 2023.1.1-h59b6b97_48682
#   dask                             2023.6.0-py311haa95532_0 --> 2024.5.0-py311haa95532_0
#   dask-core                        2023.6.0-py311haa95532_0 --> 2024.5.0-py311haa95532_0
#   datashader                         0.15.2-py311haa95532_0 --> 0.16.0-py311haa95532_0
#   dill                                0.3.6-py311haa95532_0 --> 0.3.8-py311haa95532_0
#   distributed                      2023.6.0-py311haa95532_0 --> 2024.5.0-py311haa95532_0
#   filelock                            3.9.0-py311haa95532_0 --> 3.13.1-py311haa95532_0
#   flake8                              6.0.0-py311haa95532_0 --> 7.0.0-py311haa95532_0
#   flask                               2.2.2-py311haa95532_0 --> 2.2.5-py311haa95532_0
#   fmt                                      9.1.0-h6d14046_0 --> 9.1.0-h6d14046_1
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-py~ --> pkgs/main/win-64::fonttools-4.51.0-py311h2bbff1b_0
#   frozenlist                          1.3.3-py311h2bbff1b_0 --> 1.4.0-py311h2bbff1b_0
#   fsspec                           2023.4.0-py311haa95532_0 --> 2024.3.1-py311haa95532_0
#   gflags                                   2.2.2-ha925a31_0 --> 2.2.2-hd77b12b_1
#   glog                                     0.5.0-hd77b12b_0 --> 0.5.0-hd77b12b_1
#   greenlet                            2.0.1-py311hd77b12b_0 --> 3.0.1-py311hd77b12b_0
#   holoviews                          1.17.1-py311haa95532_0 --> 1.18.3-py311haa95532_0
#   huggingface_hub                    0.15.1-py311haa95532_0 --> 0.20.3-py311haa95532_0
#   hvplot                              0.8.4-py311haa95532_0 --> 0.10.0-py311haa95532_0
#   icu                                       58.2-ha925a31_3 --> 73.1-h6c2663c_0
#   idna                                  3.4-py311haa95532_0 --> 3.7-py311haa95532_0
#   imageio                            2.26.0-py311haa95532_0 --> 2.33.1-py311haa95532_0
#   imbalanced-learn                   0.10.1-py311haa95532_1 --> 0.11.0-py311haa95532_1
#   importlib-metadata                  6.0.0-py311haa95532_0 --> 7.0.1-py311haa95532_0
#   importlib_metadata                       6.0.0-hd3eb1b0_0 --> 7.0.1-hd3eb1b0_0
#   incremental                           21.3.0-pyhd3eb1b0_0 --> 22.10.0-pyhd3eb1b0_0
#   intel-openmp                      2023.1.0-h59b6b97_46319 --> 2023.1.0-h59b6b97_46320
#   ipykernel                          6.25.0-py311h746a85d_0 --> 6.28.0-py311haa95532_0
#   ipython                            8.15.0-py311haa95532_0 --> 8.20.0-py311haa95532_0
#   ipywidgets                          8.0.4-py311haa95532_0 --> 8.1.2-py311haa95532_0
#   itemloaders        pkgs/main/noarch::itemloaders-1.0.4-p~ --> pkgs/main/win-64::itemloaders-1.1.0-py311haa95532_0
#   jinja2                              3.1.2-py311haa95532_0 --> 3.1.3-py311haa95532_0
#   jmespath           pkgs/main/noarch::jmespath-0.10.0-pyh~ --> pkgs/main/win-64::jmespath-1.0.1-py311haa95532_0
#   joblib                              1.2.0-py311haa95532_0 --> 1.4.0-py311haa95532_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/win-64::jsonpatch-1.33-py311haa95532_1
#   jsonschema                         4.17.3-py311haa95532_0 --> 4.19.2-py311haa95532_0
#   jupyter                             1.0.0-py311haa95532_8 --> 1.0.0-py311haa95532_9
#   jupyter_client                      7.4.9-py311haa95532_0 --> 8.6.0-py311haa95532_0
#   jupyter_core                        5.3.0-py311haa95532_0 --> 5.5.0-py311haa95532_0
#   jupyter_events                      0.6.3-py311haa95532_0 --> 0.8.0-py311haa95532_0
#   jupyter_server                     1.23.4-py311haa95532_0 --> 2.10.0-py311haa95532_0
#   jupyterlab                          3.6.3-py311haa95532_0 --> 4.0.11-py311haa95532_0
#   jupyterlab_server                  2.22.0-py311haa95532_0 --> 2.25.1-py311haa95532_0
#   jupyterlab_widgets                  3.0.5-py311haa95532_0 --> 3.0.10-py311haa95532_0
#   keyring                           23.13.1-py311haa95532_0 --> 24.3.1-py311haa95532_0
#   lazy-object-proxy                   1.6.0-py311h2bbff1b_0 --> 1.10.0-py311h2bbff1b_0
#   lazy_loader                           0.2-py311haa95532_0 --> 0.3-py311haa95532_0
#   libarchive                               3.6.2-hb62f4d4_2 --> 3.6.2-hb62f4d4_3
#   libboost                                1.82.0-hae598e9_1 --> 1.82.0-h3399ecb_2
#   libbrotlicommon                          1.0.9-h2bbff1b_7 --> 1.0.9-h2bbff1b_8
#   libbrotlidec                             1.0.9-h2bbff1b_7 --> 1.0.9-h2bbff1b_8
#   libbrotlienc                             1.0.9-h2bbff1b_7 --> 1.0.9-h2bbff1b_8
#   libcurl                                  8.1.1-h86230a5_0 --> 8.7.1-h86230a5_0
#   libdeflate                                1.17-h2bbff1b_0 --> 1.17-h2bbff1b_1
#   libffi                                   3.4.4-hd77b12b_0 --> 3.4.4-hd77b12b_1
#   libiconv                                  1.16-h2bbff1b_2 --> 1.16-h2bbff1b_3
#   libmamba                                 1.5.1-hcd6fe79_0 --> 1.5.8-h99b1521_2
#   libmambapy                          1.5.1-py311h77c03ed_0 --> 1.5.8-py311h77c03ed_2
#   libpq                                    12.15-h906ac69_1 --> 12.17-h906ac69_0
#   libsolv                                 0.7.24-h23ce68f_0 --> 0.7.24-h23ce68f_1
#   libssh2                                 1.10.0-he2ea4bf_2 --> 1.11.0-h291bd65_0
#   libxml2                                 2.10.4-h0ad7f3c_1 --> 2.10.4-h0ad7f3c_2
#   llvmlite                           0.40.0-py311hf2fb9eb_0 --> 0.42.0-py311hf2fb9eb_0
#   lxml                                4.9.3-py311h09808a7_0 --> 5.2.1-py311h09808a7_0
#   lz4-c                                    1.9.4-h2bbff1b_0 --> 1.9.4-h2bbff1b_1
#   markupsafe                          2.1.1-py311h2bbff1b_0 --> 2.1.3-py311h2bbff1b_0
#   matplotlib                          3.7.2-py311haa95532_0 --> 3.8.4-py311haa95532_0
#   matplotlib-base                     3.7.2-py311hf62ec03_0 --> 3.8.4-py311hf62ec03_0
#   mistune                          0.8.4-py311h2bbff1b_1000 --> 2.0.4-py311haa95532_0
#   mkl                               2023.1.0-h6b88ed4_46357 --> 2023.1.0-h6b88ed4_46358
#   more-itertools     pkgs/main/noarch::more-itertools-8.12~ --> pkgs/main/win-64::more-itertools-10.1.0-py311haa95532_0
#   multidict                           6.0.2-py311h2bbff1b_0 --> 6.0.4-py311h2bbff1b_0
#   navigator-updater                   0.4.0-py311haa95532_1 --> 0.5.0-py311haa95532_0
#   nbclient                           0.5.13-py311haa95532_0 --> 0.8.0-py311haa95532_0
#   nbconvert                           6.5.4-py311haa95532_0 --> 7.10.0-py311haa95532_0
#   nest-asyncio                        1.5.6-py311haa95532_0 --> 1.6.0-py311haa95532_0
#   notebook                            6.5.4-py311haa95532_1 --> 7.0.8-py311haa95532_0
#   notebook-shim                       0.2.2-py311haa95532_0 --> 0.2.3-py311haa95532_0
#   numba                              0.57.1-py311hf62ec03_0 --> 0.59.1-py311hf62ec03_0
#   numexpr                             2.8.4-py311h1fcbade_1 --> 2.8.7-py311h1fcbade_0
#   numpy                              1.24.3-py311hdab7c0b_1 --> 1.26.4-py311hdab7c0b_0
#   numpy-base                         1.24.3-py311hd01c5d8_1 --> 1.26.4-py311hd01c5d8_0
#   openpyxl                           3.0.10-py311h2bbff1b_0 --> 3.1.2-py311h2bbff1b_0
#   packaging                            23.1-py311haa95532_0 --> 23.2-py311haa95532_0
#   pandas                              2.0.3-py311hf62ec03_0 --> 2.2.1-py311hea22821_0
#   panel                               1.2.3-py311haa95532_0 --> 1.4.2-py311haa95532_0
#   param                              1.13.0-py311haa95532_0 --> 2.1.0-py311haa95532_0
#   parsel                              1.6.0-py311haa95532_0 --> 1.8.1-py311haa95532_0
#   partd                               1.4.0-py311haa95532_0 --> 1.4.1-py311haa95532_0
#   pcre2                                    10.42-h0ff8eda_0 --> 10.42-h0ff8eda_1
#   pillow                              9.4.0-py311hd77b12b_1 --> 10.3.0-py311h2bbff1b_0
#   pkginfo                             1.9.6-py311haa95532_0 --> 1.10.0-py311haa95532_0
#   plotly                              5.9.0-py311haa95532_0 --> 5.19.0-py311h746a85d_0
#   prompt-toolkit                     3.0.36-py311haa95532_0 --> 3.0.43-py311haa95532_0
#   prompt_toolkit                          3.0.36-hd3eb1b0_0 --> 3.0.43-hd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-py~ --> pkgs/main/win-64::py-cpuinfo-9.0.0-py311haa95532_0
#   pyarrow                            11.0.0-py311h8a3a540_1 --> 14.0.2-py311h847bd2a_0
#   pybind11-abi                                 4-hd3eb1b0_1 --> 5-hd3eb1b0_0
#   pycodestyle                        2.10.0-py311haa95532_0 --> 2.11.1-py311haa95532_0
#   pycosat                             0.6.4-py311h2bbff1b_0 --> 0.6.6-py311h2bbff1b_1
#   pydantic                           1.10.8-py311h2bbff1b_0 --> 1.10.12-py311h2bbff1b_1
#   pyflakes                            3.0.1-py311haa95532_0 --> 3.2.0-py311haa95532_0
#   pyjwt                               2.4.0-py311haa95532_0 --> 2.8.0-py311haa95532_0
#   pylint-venv                         2.3.0-py311haa95532_0 --> 3.0.3-py311haa95532_0
#   pyodbc                             4.0.34-py311hd77b12b_0 --> 5.0.1-py311hd77b12b_0
#   pyopenssl                          23.2.0-py311haa95532_0 --> 24.0.0-py311haa95532_0
#   pyqt                               5.15.7-py311hd77b12b_0 --> 5.15.10-py311hd77b12b_0
#   pyqt5-sip                         12.11.0-py311hd77b12b_0 --> 12.13.0-py311h2bbff1b_0
#   pyqtwebengine                      5.15.7-py311hd77b12b_0 --> 5.15.10-py311hd77b12b_0
#   pytables                            3.8.0-py311h4671533_3 --> 3.9.2-py311h91a9f6a_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8~ --> pkgs/main/win-64::python-dateutil-2.9.0post0-py311haa95532_0
#   python-lsp-black                    1.2.1-py311haa95532_0 --> 2.0.0-py311haa95532_0
#   python-lsp-jsonrpc                     1.0.0-pyhd3eb1b0_0 --> 1.1.2-pyhd3eb1b0_0
#   python-lsp-server                   1.7.2-py311haa95532_0 --> 1.10.0-py311haa95532_0
#   pytoolconfig                        1.2.5-py311haa95532_1 --> 1.2.6-py311haa95532_0
#   pytz                         2023.3.post1-py311haa95532_0 --> 2024.1-py311haa95532_0
#   pyviz_comms                         2.3.0-py311haa95532_0 --> 3.0.2-py311haa95532_0
#   pywavelets                          1.4.1-py311h2bbff1b_0 --> 1.5.0-py311hd7041d2_0
#   pywin32-ctypes                   0.2.0-py311haa95532_1000 --> 0.2.2-py311haa95532_0
#   pyyaml                                6.0-py311h2bbff1b_1 --> 6.0.1-py311h2bbff1b_0
#   pyzmq                              23.2.0-py311hd77b12b_0 --> 25.1.2-py311hd77b12b_0
#   qdarkstyle                             3.0.2-pyhd3eb1b0_0 --> 3.2.3-pyhd3eb1b0_0
#   qt-main                                 5.15.2-h879a1e9_9 --> 5.15.2-h19c9488_10
#   qtconsole                           5.4.2-py311haa95532_0 --> 5.5.1-py311haa95532_0
#   qtpy                                2.2.0-py311haa95532_0 --> 2.4.1-py311haa95532_0
#   queuelib                            1.5.0-py311haa95532_0 --> 1.6.2-py311haa95532_0
#   regex                            2022.7.9-py311h2bbff1b_0 --> 2023.10.3-py311h2bbff1b_0
#   reproc                                  14.2.4-hd77b12b_1 --> 14.2.4-hd77b12b_2
#   reproc-cpp                              14.2.4-hd77b12b_1 --> 14.2.4-hd77b12b_2
#   requests                           2.31.0-py311haa95532_0 --> 2.31.0-py311haa95532_1
#   rope                                1.7.0-py311haa95532_0 --> 1.12.0-py311haa95532_0
#   s3fs                             2023.4.0-py311haa95532_0 --> 2024.3.1-py311haa95532_0
#   safetensors                         0.3.2-py311h062c2fa_0 --> 0.4.2-py311hcbdf901_0
#   scikit-image                       0.20.0-py311h3513d60_0 --> 0.22.0-py311hb4ba03d_0
#   scikit-learn                        1.3.0-py311hf62ec03_0 --> 1.4.2-py311hf62ec03_1
#   scipy                              1.11.1-py311hc1ccb85_0 --> 1.13.0-py311h9f229c6_0
#   scrapy                              2.8.0-py311haa95532_0 --> 2.11.1-py311haa95532_0
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-py~ --> pkgs/main/win-64::send2trash-1.8.2-py311haa95532_0
#   sip                                 6.6.2-py311hd77b12b_0 --> 6.7.12-py311hd77b12b_0
#   snappy                                   1.1.9-h6c2663c_0 --> 1.1.10-h6c2663c_1
#   sniffio                             1.2.0-py311haa95532_1 --> 1.3.0-py311haa95532_0
#   soupsieve                             2.4-py311haa95532_0 --> 2.5-py311haa95532_0
#   spyder                              5.4.3-py311haa95532_1 --> 5.5.1-py311haa95532_0
#   spyder-kernels                      2.4.4-py311haa95532_0 --> 2.5.0-py311haa95532_0
#   sqlalchemy                         1.4.39-py311h2bbff1b_0 --> 2.0.25-py311h2bbff1b_0
#   sqlite                                  3.41.2-h2bbff1b_0 --> 3.45.3-h2bbff1b_0
#   sympy                              1.11.1-py311haa95532_0 --> 1.12-py311haa95532_0
#   tabulate                           0.8.10-py311haa95532_0 --> 0.9.0-py311haa95532_0
#   tk                                      8.6.12-h2bbff1b_0 --> 8.6.14-h0416ee5_0
#   tokenizers                         0.13.2-py311h49fca51_1 --> 0.15.1-py311h49fca51_0
#   tornado                             6.3.2-py311h2bbff1b_0 --> 6.3.3-py311h2bbff1b_0
#   tqdm                               4.65.0-py311h746a85d_0 --> 4.66.2-py311h746a85d_0
#   transformers                       4.32.1-py311haa95532_0 --> 4.37.2-py311haa95532_0
#   twisted                           22.10.0-py311h2bbff1b_0 --> 23.10.0-py311haa95532_0
#   typing-extensions                   4.7.1-py311haa95532_0 --> 4.11.0-py311haa95532_0
#   typing_extensions                   4.7.1-py311haa95532_0 --> 4.11.0-py311haa95532_0
#   tzdata                                   2023c-h04d1e81_0 --> 2024a-h04d1e81_0
#   urllib3                           1.26.16-py311haa95532_0 --> 2.2.1-py311haa95532_0
#   utf8proc                                 2.6.1-h2bbff1b_0 --> 2.6.1-h2bbff1b_1
#   vs2015_runtime                     14.27.29016-h5e58377_2 --> 14.29.30133-h43f2093_3
#   w3lib              pkgs/main/noarch::w3lib-1.21.0-pyhd3e~ --> pkgs/main/win-64::w3lib-2.1.2-py311haa95532_0
#   websocket-client                   0.58.0-py311haa95532_4 --> 1.8.0-py311haa95532_0
#   widgetsnbextension                  4.0.5-py311haa95532_0 --> 4.0.10-py311haa95532_0
#   xz                                       5.4.2-h8cc25b3_0 --> 5.4.6-h8cc25b3_1
#   yaml-cpp                                 0.7.0-hd77b12b_1 --> 0.8.0-hd77b12b_1
#   yapf               pkgs/main/noarch::yapf-0.31.0-pyhd3eb~ --> pkgs/main/win-64::yapf-0.40.2-py311haa95532_0
#   yarl                                1.8.1-py311h2bbff1b_0 --> 1.9.3-py311h2bbff1b_0
#   zeromq                                   4.3.4-hd77b12b_0 --> 4.3.5-hd77b12b_0
#   zict                                2.2.0-py311haa95532_0 --> 3.0.0-py311haa95532_0
#   zipp                               3.11.0-py311haa95532_0 --> 3.17.0-py311haa95532_0
#   zlib                                    1.2.13-h8cc25b3_0 --> 1.2.13-h8cc25b3_1
#   zstandard                          0.19.0-py311h2bbff1b_0 --> 0.22.0-py311h3469f8a_0
#   zstd                                     1.5.5-hd43e919_0 --> 1.5.5-hd43e919_2
#
# The following packages will be DOWNGRADED:
#
#   vc                                        14.2-h21ff451_1 --> 14.2-h2eaa2aa_1
#
#
#
# Downloading and Extracting Packages
#
# zlib-1.2.13          | 131 KB    |            |   0%
#
# unicodedata2-15.1.0  | 521 KB    |            |   0%
#
#
# mpir-3.0.0           | 1.3 MB    |            |   0%
#
#
#
# pcre2-10.42          | 728 KB    |            |   0%
#
#
#
#
# tomli-2.0.1          | 31 KB     |            |   0%
#
#
#
#
#
# cytoolz-0.12.2       | 339 KB    |            |   0%
#
#
#
#
#
#
# conda-index-0.4.0    | 173 KB    |            |   0%
#
#
#
#
#
#
#
# overrides-7.4.0      | 38 KB     |            |   0%
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 152 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.0         | 531 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.4.1          | 49 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 645 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.5.0   | 112 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter-lsp-2.2.0    | 107 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 347 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# zlib-1.2.13          | 131 KB    | #2         |  12%
#
#
#
# pcre2-10.42          | 728 KB    | 2          |   2%
#
# unicodedata2-15.1.0  | 521 KB    | 3          |   3%
#
#
#
#
# tomli-2.0.1          | 31 KB     | #####2     |  52%
#
#
#
#
#
# cytoolz-0.12.2       | 339 KB    | 4          |   5%
# zlib-1.2.13          | 131 KB    | ########## | 100%
# zlib-1.2.13          | 131 KB    | ########## | 100%
#
#
#
# pcre2-10.42          | 728 KB    | ######8    |  68%
#
# unicodedata2-15.1.0  | 521 KB    | #####5     |  55%
#
#
#
#
#
#
# conda-index-0.4.0    | 173 KB    | 9          |   9%
#
#
# mpir-3.0.0           | 1.3 MB    | 1          |   1%
#
#
#
#
# tomli-2.0.1          | 31 KB     | ########## | 100%
#
#
#
#
# tomli-2.0.1          | 31 KB     | ########## | 100%
#
#
#
#
#
#
#
# overrides-7.4.0      | 38 KB     | ####2      |  43%
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | #          |  10%
#
#
# mpir-3.0.0           | 1.3 MB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 152 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.0         | 531 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.4.1          | 49 KB     | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 645 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter-lsp-2.2.0    | 107 KB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.5.0   | 112 KB    | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 347 KB    | 4          |   5%
#
#
#
#
#
# cytoolz-0.12.2       | 339 KB    | ########## | 100%
#
#
#
#
#
# cytoolz-0.12.2       | 339 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | 7          |   8%
#
# unicodedata2-15.1.0  | 521 KB    | ########## | 100%
#
# unicodedata2-15.1.0  | 521 KB    | ########## | 100%
#
#
#
#
#
#
# conda-index-0.4.0    | 173 KB    | ########## | 100%
#
#
#
#
#
#
# conda-index-0.4.0    | 173 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    | ########5  |  86%
#
#
#
#
#
#
#
# overrides-7.4.0      | 38 KB     | ########## | 100%
#
#
#
#
#
#
#
# overrides-7.4.0      | 38 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #          |  10%
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 152 KB    | ########## | 100%
#
#
#
# pcre2-10.42          | 728 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #3         |  14%
#
#
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.4.1          | 49 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.4.1          | 49 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #5         |  15%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #9         |  20%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.5.0   | 112 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.5.0   | 112 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 645 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imageio-2.33.1       | 645 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 347 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-python-1.0.9  | 347 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.0         | 531 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.0         | 531 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter-lsp-2.2.0    | 107 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter-lsp-2.2.0    | 107 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mistune-2.0.4        | 108 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #########  |  91%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.10.55  | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# panel-1.4.2          | 18.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(188): Could not remove or rename C:\Users\Dell\anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf.  Please remove this file manually (you may need to reboot to free file handles)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load pre-trained model and tokenizer
model_name = "microsoft/DialoGPT-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side='left')
model = AutoModelForCausalLM.from_pretrained(model_name)

# Function to generate responses
def chatbot_response(user_input, chat_history_ids=None):
    # Tokenize the user input
    new_user_input_ids = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')
    
    # Get the chat history ids (append the new input)
    if chat_history_ids is not None:
        bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1)
    else:
        bot_input_ids = new_user_input_ids
    
    # Generate a response
    chat_history_ids = model.generate(bot_input_ids, max_length=1000, pad_token_id=tokenizer.eos_token_id, do_sample=True, top_k=50, top_p=0.95, temperature=0.7)
    
    # Decode the response
    response = tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)
    
    return response, chat_history_ids

# Interactive loop to test the chatbot
print("Chatbot is ready to chat! Type 'exit' to end the conversation.")
chat_history_ids = None
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye!")
        break
    response, chat_history_ids = chatbot_response(user_input, chat_history_ids)
    print("Chatbot:", response)
# Out:
# Chatbot is ready to chat! Type 'exit' to end the conversation.
# You:  can your code be adjusted to suit elderly wearable tech chatbot?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: Sure, PM me.
# You:  What is "PM me" mean?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: I meant it as a joke.
# You:  Well, can you answer seriously?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: Can you?
# You:  how to control your humour settings?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: I don't know. I'm not a comedian.
# You:  but you are a chatbot
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: Chatbots are people too!
# You:  you think so?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: Well, I'm not a robot.
# You:  exit!
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: The doors are open!
# You:  you are smart arent you?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Chatbot: Not sure
# You:  exit
# Chatbot: Goodbye!
